# %% [markdown]
# # 1- Machine Learning Loyiha

# %%
# Kutubxonalarni yuklash
# !pip install pandas

# %%
# !pip install numpy

# %%
# !pip install seaborn

# %%
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sbs
import matplotlib.pyplot as plt

# %%
#Pandas
# Datani vs codega olish

df=pd.read_csv('telefon turini aniqlash.csv')

# %%
# datani tekshirish
df.head()   #  boshidan 5 ta element
# Out:
#    battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0              842       0                 2.2                   0
# 1             1021       1                 0.5                   1
# 2              563       1                 0.5                   1
# 3              615       1                 2.5                   0
# 4             1821       1                 1.2                   0
#
#    Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi  Vazni  \
# 0            1   0             7               0.6    188
# 1            0   1            53               0.7    136
# 2            2   1            41               0.9    145
# 3            0   0            10               0.8    131
# 4           13   1            44               0.6    141
#
#    Protsessor yadrolari soni  ...  Qurilma xajmi(pix)  \
# 0                          2  ...                  20
# 1                          3  ...                 905
# ...

# %%
df.head(1)  #  boshidan 1 ta element
# Out:
#    battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0              842       0                 2.2                   0
#
#    Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi  Vazni  \
# 0            1   0             7               0.6    188
#
#    Protsessor yadrolari soni  ...  Qurilma xajmi(pix)  \
# 0                          2  ...                  20
#
#    Qurilma ekran kengligi(pix)   ram  Qurilma xajmi(cm)  \
# 0                          756  2549                  9
#
#    Qurilma ekran kengligi(cm)  Bir_quvvatlashdagi gaplashish  3g  sensorli  \
# 0                           7                             19   0         0
#
#    wifi  Qanday telefon
# 0     1               1
#
# [1 rows x 21 columns]

# %%
df.tail() #  oxiridan 5 ta element
# Out:
#       battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 1995              794       1                 0.5                   1
# 1996             1965       1                 2.6                   1
# 1997             1911       0                 0.9                   1
# 1998             1512       0                 0.9                   0
# 1999              510       1                 2.0                   1
#
#       Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi  Vazni  \
# 1995            0   1             2               0.8    106
# 1996            0   0            39               0.2    187
# 1997            1   1            36               0.7    108
# 1998            4   1            46               0.1    145
# 1999            5   1            45               0.9    168
#
#       Protsessor yadrolari soni  ...  Qurilma xajmi(pix)  \
# 1995                          6  ...                1222
# 1996                          4  ...                 915
# ...

# %%
#ustunni tekshirish

df['protsessor_tezligi']
# Out:
# 0       2.2
# 1       0.5
# 2       0.5
# 3       2.5
# 4       1.2
#        ...
# 1995    0.5
# 1996    2.6
# 1997    0.9
# 1998    0.9
# 1999    2.0
# Name: protsessor_tezligi, Length: 2000, dtype: float64

# %%
# Yangi input(feature yaratish)
df['protsessor_tezligi_ratio']=df['protsessor_tezligi']/100

# %%
df.head(5)
# Out:
#    battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0              842       0                 2.2                   0
# 1             1021       1                 0.5                   1
# 2              563       1                 0.5                   1
# 3              615       1                 2.5                   0
# 4             1821       1                 1.2                   0
#
#    Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi  Vazni  \
# 0            1   0             7               0.6    188
# 1            0   1            53               0.7    136
# 2            2   1            41               0.9    145
# 3            0   0            10               0.8    131
# 4           13   1            44               0.6    141
#
#    Protsessor yadrolari soni  ...  Qurilma xajmi(pix)  \
# 0                          2  ...                  20
# 1                          3  ...                 905
# ...

# %%
#Kerak emas ustunni tashlab yuborish
df.drop('protsessor_tezligi_ratio', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 #Kerak emas ustunni tashlab yuborish
# ----> 2 df.drop('protsessor_tezligi_ratio', axis=1, inplace=True)
#
# File c:\Users\davro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
# ...

# %%
df.head()
# Out:
#    battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0              842       0                 2.2                   0
# 1             1021       1                 0.5                   1
# 2              563       1                 0.5                   1
# 3              615       1                 2.5                   0
# 4             1821       1                 1.2                   0
#
#    Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi  Vazni  \
# 0            1   0             7               0.6    188
# 1            0   1            53               0.7    136
# 2            2   1            41               0.9    145
# 3            0   0            10               0.8    131
# 4           13   1            44               0.6    141
#
#    Protsessor yadrolari soni  ...  Qurilma xajmi(pix)  \
# 0                          2  ...                  20
# 1                          3  ...                 905
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
#Data xaqida umumiy malumot
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2000 non-null   int64
#  1   blutus                         2000 non-null   int64
#  2   protsessor_tezligi             2000 non-null   float64
#  3   ikkita simkartalik             2000 non-null   int64
#  4   Oldi_kamera                    2000 non-null   int64
#  5   4G                             2000 non-null   int64
#  6   Ichki_xotira                   2000 non-null   int64
#  7   tel_ingichgaligi               2000 non-null   float64
#  8   Vazni                          2000 non-null   int64
#  9   Protsessor yadrolari soni      2000 non-null   int64
#  10  Asosiy kamera                  2000 non-null   int64
#  11  Qurilma xajmi(pix)             2000 non-null   int64
# ...

# %%
#
df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# tel_ingichgaligi                 0
# Vazni                            0
# Protsessor yadrolari soni        0
# Asosiy kamera                    0
# Qurilma xajmi(pix)               0
# Qurilma ekran kengligi(pix)      0
# ram                              0
# Qurilma xajmi(cm)                0
# Qurilma ekran kengligi(cm)       0
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# sensorli                         0
# wifi                             0
# Qanday telefon                   0
# dtype: int64

# %%
df.describe()
# Out:
#        battereya_hajmi     blutus  protsessor_tezligi  ikkita simkartalik  \
# count      2000.000000  2000.0000         2000.000000         2000.000000
# mean       1238.518500     0.4950            1.522250            0.509500
# std         439.418206     0.5001            0.816004            0.500035
# min         501.000000     0.0000            0.500000            0.000000
# 25%         851.750000     0.0000            0.700000            0.000000
# 50%        1226.000000     0.0000            1.500000            1.000000
# 75%        1615.250000     1.0000            2.200000            1.000000
# max        1998.000000     1.0000            3.000000            1.000000
#
#        Oldi_kamera           4G  Ichki_xotira  tel_ingichgaligi        Vazni  \
# count  2000.000000  2000.000000   2000.000000       2000.000000  2000.000000
# mean      4.309500     0.521500     32.046500          0.501750   140.249000
# ...

# %%
                       UYGA vazifa

# %%
a=6
b=5
print(a+b)
# Out:
# 11

# %%
print(a-b)
# Out:
# 1

# %%
print(a*b)
# Out:
# 30

# %%
print(a/b)
# Out:
# 1.2

# %%
print(a//b)
# Out:
# 1

# %%
print(a%b)
# Out:
# 1

# %%
print(a**b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(a**b)
#
# NameError: name 'a' is not defined

# %%
a>b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a>b
#
# NameError: name 'a' is not defined

# %%
(a+b)/2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 (a+b)/2
#
# NameError: name 'a' is not defined
